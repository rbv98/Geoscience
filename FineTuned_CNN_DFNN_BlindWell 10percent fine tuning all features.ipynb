# %%
# in this code i am using 10% of blind well for fine tunning. its results are best so far.
# next step i will text with 15%
# i will test adding layers
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential, clone_model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization, Input
from tensorflow.keras.models import load_model
from tensorflow.keras.losses import MeanSquaredError
from sklearn.model_selection import train_test_split
import csv

print("✅ Libraries loaded.")
# Out:
# /Users/IDEAPAD/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ✅ Libraries loaded.

# %%
blind_labeled_file = 'MISSA KESWAL-02.CSV'
delim = ','
df_blind = pd.read_csv(blind_labeled_file, delimiter=delim)
df_blind.columns = df_blind.columns.str.strip().str.lower()
df_blind.replace(-999.25, np.nan, inplace=True)

features = ['gr', 'dt', 'dt_nct', 'rhob_combined', 'res_deep', 'sphi', 'hp', 'ob']
depth_col = 'depth'
target_col = 'ppp'

df_blind.dropna(subset=features + [depth_col, target_col], inplace=True)
df_finetune, df_blind_val = train_test_split(df_blind, test_size=0.9, random_state=42)

print(f"✅ Fine-tuning samples: {len(df_finetune)} | Validation samples: {len(df_blind_val)}")
# Out:
# ✅ Fine-tuning samples: 519 | Validation samples: 4671

# %%
scaler = StandardScaler()
X_finetune = scaler.fit_transform(df_finetune[features])
y_finetune = df_finetune[target_col].values
X_val = scaler.transform(df_blind_val[features])
y_val = df_blind_val[target_col].values

X_finetune_cnn = X_finetune.reshape((X_finetune.shape[0], X_finetune.shape[1], 1))
X_val_cnn = X_val.reshape((X_val.shape[0], X_val.shape[1], 1))

print("✅ Data scaled and reshaped.")
# Out:
# ✅ Data scaled and reshaped.

# %%
model_path = '/Users/IDEAPAD/Documents/Research work/Geoscience project/Well Data/PPCNN/cnn_model.h5'
cnn = load_model(model_path, compile=False)

cnn.compile(optimizer='adam', loss=MeanSquaredError())

cnn_finetuned = clone_model(cnn)
cnn_finetuned.set_weights(cnn.get_weights())
cnn_finetuned.compile(optimizer='adam', loss='mse')

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5, min_lr=1e-6)

cnn_finetuned.fit(X_finetune_cnn, y_finetune,
                  validation_data=(X_val_cnn, y_val),
                  epochs=100,
                  batch_size=16,
                  callbacks=[early_stop, reduce_lr],
                  verbose=1)

print("✅ CNN fine-tuning complete.")
# Out:
# Epoch 1/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 730365.5625 - val_loss: 420878.4062 - learning_rate: 0.0010
# Epoch 2/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 521541.1250 - val_loss: 339400.4688 - learning_rate: 0.0010
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 380361.3125 - val_loss: 326316.8438 - learning_rate: 0.0010
# Epoch 4/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 328562.8438 - val_loss: 303377.6562 - learning_rate: 0.0010
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 394202.7500 - val_loss: 282995.3125 - learning_rate: 0.0010
# Epoch 6/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 333916.5625 - val_loss: 272417.6562 - learning_rate: 0.0010
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 350026.5938 - val_loss: 272225.9688 - learning_rate: 0.0010
# Epoch 8/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 384789.0000 - val_loss: 263606.0938 - learning_rate: 0.0010
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 294832.3438 - val_loss: 259220.4688 - learning_rate: 0.0010
# Epoch 10/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 351055.6250 - val_loss: 251141.7500 - learning_rate: 0.0010
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 332158.4375 - val_loss: 249680.1562 - learning_rate: 0.0010
# Epoch 12/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 303662.0625 - val_loss: 250453.4219 - learning_rate: 0.0010
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 281236.1250 - val_loss: 236680.2188 - learning_rate: 0.0010
# Epoch 14/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 322599.6875 - val_loss: 241505.9062 - learning_rate: 0.0010
# Epoch 15/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 282743.5938 - val_loss: 232899.3594 - learning_rate: 0.0010
# Epoch 16/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 313586.2188 - val_loss: 242191.2344 - learning_rate: 0.0010
# Epoch 17/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 281215.7500 - val_loss: 228007.7344 - learning_rate: 0.0010
# Epoch 18/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 285261.6875 - val_loss: 226851.2500 - learning_rate: 0.0010
# Epoch 19/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 286487.6875 - val_loss: 225249.7188 - learning_rate: 0.0010
# Epoch 20/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 256225.3750 - val_loss: 222496.2500 - learning_rate: 0.0010
# Epoch 21/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 320634.1250 - val_loss: 225540.1094 - learning_rate: 0.0010
# Epoch 22/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 291294.1250 - val_loss: 228324.4531 - learning_rate: 0.0010
# Epoch 23/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 273976.8125 - val_loss: 212913.5156 - learning_rate: 0.0010
# Epoch 24/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 272278.5625 - val_loss: 221324.6406 - learning_rate: 0.0010
# Epoch 25/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 293505.5625 - val_loss: 220417.9531 - learning_rate: 0.0010
# Epoch 26/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 248309.8750 - val_loss: 214294.2344 - learning_rate: 0.0010
# Epoch 27/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 242356.5156 - val_loss: 212497.9375 - learning_rate: 0.0010
# Epoch 28/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 288970.2812 - val_loss: 212524.1250 - learning_rate: 0.0010
# Epoch 29/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 263199.9375 - val_loss: 214137.9375 - learning_rate: 0.0010
# Epoch 30/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 249613.7656 - val_loss: 232279.6094 - learning_rate: 0.0010
# Epoch 31/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 287384.4375 - val_loss: 213737.6250 - learning_rate: 0.0010
# Epoch 32/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 288023.7500 - val_loss: 215100.7500 - learning_rate: 0.0010
# Epoch 33/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 249268.2344 - val_loss: 212588.6406 - learning_rate: 5.0000e-04
# Epoch 34/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 254452.0625 - val_loss: 206829.0156 - learning_rate: 5.0000e-04
# Epoch 35/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 259526.9688 - val_loss: 208187.7812 - learning_rate: 5.0000e-04
# Epoch 36/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 263771.4375 - val_loss: 205961.6094 - learning_rate: 5.0000e-04
# Epoch 37/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 310339.9688 - val_loss: 207874.6250 - learning_rate: 5.0000e-04
# Epoch 38/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 257140.1719 - val_loss: 207614.1250 - learning_rate: 5.0000e-04
# Epoch 39/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 252086.5312 - val_loss: 208978.9688 - learning_rate: 5.0000e-04
# Epoch 40/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 266289.5312 - val_loss: 204592.3125 - learning_rate: 5.0000e-04
# Epoch 41/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 269745.3750 - val_loss: 206305.5625 - learning_rate: 5.0000e-04
# Epoch 42/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 316151.2812 - val_loss: 204701.5156 - learning_rate: 5.0000e-04
# Epoch 43/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 274413.5000 - val_loss: 209136.6094 - learning_rate: 5.0000e-04
# Epoch 44/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 251008.7031 - val_loss: 205393.9375 - learning_rate: 5.0000e-04
# Epoch 45/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 255458.2500 - val_loss: 207195.2188 - learning_rate: 5.0000e-04
# Epoch 46/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 299460.5938 - val_loss: 205385.0781 - learning_rate: 2.5000e-04
# Epoch 47/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 250487.2656 - val_loss: 208411.4531 - learning_rate: 2.5000e-04
# Epoch 48/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 250302.8438 - val_loss: 208086.8750 - learning_rate: 2.5000e-04
# Epoch 49/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 242481.9219 - val_loss: 206688.6406 - learning_rate: 2.5000e-04
# Epoch 50/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 305390.9062 - val_loss: 203260.2031 - learning_rate: 2.5000e-04
# Epoch 51/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 244215.2031 - val_loss: 204912.0469 - learning_rate: 2.5000e-04
# Epoch 52/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 256467.4844 - val_loss: 203936.3125 - learning_rate: 2.5000e-04
# Epoch 53/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 285771.8125 - val_loss: 201710.4531 - learning_rate: 2.5000e-04
# Epoch 54/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 247042.4219 - val_loss: 200347.2812 - learning_rate: 2.5000e-04
# Epoch 55/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 288105.0000 - val_loss: 200874.7656 - learning_rate: 2.5000e-04
# Epoch 56/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 285563.0000 - val_loss: 202562.7344 - learning_rate: 2.5000e-04
# Epoch 57/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 260108.0000 - val_loss: 202417.2969 - learning_rate: 2.5000e-04
# Epoch 58/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 242444.9219 - val_loss: 203477.0938 - learning_rate: 2.5000e-04
# Epoch 59/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 242529.0938 - val_loss: 202376.2188 - learning_rate: 2.5000e-04
# Epoch 60/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 267258.2812 - val_loss: 202158.9375 - learning_rate: 1.2500e-04
# Epoch 61/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 290479.3438 - val_loss: 200675.7500 - learning_rate: 1.2500e-04
# Epoch 62/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 214149.9844 - val_loss: 199917.8594 - learning_rate: 1.2500e-04
# Epoch 63/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 262928.3438 - val_loss: 198481.5625 - learning_rate: 1.2500e-04
# Epoch 64/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 292583.2500 - val_loss: 199638.3438 - learning_rate: 1.2500e-04
# Epoch 65/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 279421.2812 - val_loss: 200305.0000 - learning_rate: 1.2500e-04
# Epoch 66/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 264864.3438 - val_loss: 200928.8750 - learning_rate: 1.2500e-04
# Epoch 67/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 242742.9844 - val_loss: 198702.1719 - learning_rate: 1.2500e-04
# Epoch 68/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 249416.7188 - val_loss: 199380.2812 - learning_rate: 1.2500e-04
# Epoch 69/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 256234.4688 - val_loss: 200124.5156 - learning_rate: 6.2500e-05
# Epoch 70/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 232785.1250 - val_loss: 199102.2031 - learning_rate: 6.2500e-05
# Epoch 71/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 231205.2812 - val_loss: 199044.7656 - learning_rate: 6.2500e-05
# Epoch 72/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 262696.1562 - val_loss: 197967.5469 - learning_rate: 6.2500e-05
# Epoch 73/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 257273.9375 - val_loss: 198833.7656 - learning_rate: 6.2500e-05
# Epoch 74/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 252038.7031 - val_loss: 198084.8750 - learning_rate: 6.2500e-05
# Epoch 75/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 292840.7188 - val_loss: 197660.5469 - learning_rate: 6.2500e-05
# Epoch 76/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 270478.2812 - val_loss: 197396.1719 - learning_rate: 6.2500e-05
# Epoch 77/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 284720.6875 - val_loss: 196738.2656 - learning_rate: 6.2500e-05
# Epoch 78/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 296323.5000 - val_loss: 197546.8438 - learning_rate: 6.2500e-05
# Epoch 79/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 252375.2969 - val_loss: 199149.3750 - learning_rate: 6.2500e-05
# Epoch 80/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 221030.4531 - val_loss: 199381.9219 - learning_rate: 6.2500e-05
# Epoch 81/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 255442.4688 - val_loss: 199126.3125 - learning_rate: 6.2500e-05
# Epoch 82/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 237434.3438 - val_loss: 198485.5312 - learning_rate: 6.2500e-05
# Epoch 83/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 265114.4375 - val_loss: 198230.2812 - learning_rate: 3.1250e-05
# Epoch 84/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 243258.6094 - val_loss: 197809.8125 - learning_rate: 3.1250e-05
# Epoch 85/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 274411.3125 - val_loss: 198179.7500 - learning_rate: 3.1250e-05
# Epoch 86/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 294255.8750 - val_loss: 198388.5469 - learning_rate: 3.1250e-05
# Epoch 87/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 254335.7656 - val_loss: 198334.1719 - learning_rate: 3.1250e-05
# ✅ CNN fine-tuning complete.

# %%
y_pred_val_cnn = cnn_finetuned.predict(X_val_cnn).flatten()

def evaluate_model(name, y_true, y_pred):
    r2 = r2_score(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    rel_rmse = (rmse / (max(y_true) - min(y_true))) * 100
    print(f"📊 {name}:")
    print(f"   R²     : {r2:.4f}")
    print(f"   MSE    : {mse:.2f}")
    print(f"   RMSE   : {rmse:.2f}")
    print(f"   MAE    : {mae:.2f}")
    print(f"   Rel RMSE: {rel_rmse:.2f}% of PPP range\n")

evaluate_model("CNN (Fine-Tuned on Blind Well)", y_val, y_pred_val_cnn)

# Plot
depth_val = df_blind_val[depth_col].values
sorted_idx = np.argsort(depth_val)
plt.figure(figsize=(6, 12))
plt.plot(y_val[sorted_idx], depth_val[sorted_idx], label='Actual PPP', linewidth=2)
plt.plot(y_pred_val_cnn[sorted_idx], depth_val[sorted_idx], label='Predicted PPP - CNN', linestyle='--')
plt.gca().invert_yaxis()
plt.xlabel('Pore Pressure')
plt.ylabel('Depth')
plt.title('CNN: Actual vs Predicted PPP by Depth (Blind Well)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 📊 CNN (Fine-Tuned on Blind Well):
#    R²     : 0.6801
#    MSE    : 196738.20
#    RMSE   : 443.55
#    MAE    : 331.61
#    Rel RMSE: 11.16% of PPP range

# %%
# Load and clone DFNN model
model_path = '/Users/IDEAPAD/Documents/Research work/Geoscience project/Well Data/PPCNN/dfnn_model.h5'
dfnn = load_model(model_path, compile=False)

dfnn.compile(optimizer='adam', loss=MeanSquaredError())

dfnn_finetuned = clone_model(dfnn)
dfnn_finetuned.set_weights(dfnn.get_weights())
dfnn_finetuned.compile(optimizer='adam', loss='mse')

# %%
# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5, min_lr=1e-6)

# Train on 10% blind well
dfnn_finetuned.fit(X_finetune, y_finetune,
                   validation_data=(X_val, y_val),
                   epochs=100,
                   batch_size=16,
                   callbacks=[early_stop, reduce_lr],
                   verbose=1)

print("✅ DFNN fine-tuning complete.")
# Out:
# Epoch 1/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1127951.8750 - val_loss: 795300.5000 - learning_rate: 0.0010
# Epoch 2/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 808939.3750 - val_loss: 677427.2500 - learning_rate: 0.0010
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 632672.8750 - val_loss: 605177.6875 - learning_rate: 0.0010
# Epoch 4/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 591390.2500 - val_loss: 556081.5625 - learning_rate: 0.0010
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 529429.2500 - val_loss: 501721.9062 - learning_rate: 0.0010
# Epoch 6/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 617809.8125 - val_loss: 468002.6250 - learning_rate: 0.0010
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 490160.1875 - val_loss: 432069.7812 - learning_rate: 0.0010
# Epoch 8/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 509858.4688 - val_loss: 404468.5312 - learning_rate: 0.0010
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 457730.6562 - val_loss: 396310.4375 - learning_rate: 0.0010
# Epoch 10/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 485830.0625 - val_loss: 381231.3750 - learning_rate: 0.0010
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 446773.1250 - val_loss: 364907.5625 - learning_rate: 0.0010
# Epoch 12/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 402956.1562 - val_loss: 356155.7188 - learning_rate: 0.0010
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 436057.1875 - val_loss: 344040.2188 - learning_rate: 0.0010
# Epoch 14/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 459543.1875 - val_loss: 349459.4062 - learning_rate: 0.0010
# Epoch 15/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 399315.5938 - val_loss: 323879.5938 - learning_rate: 0.0010
# Epoch 16/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 352535.6875 - val_loss: 312640.5000 - learning_rate: 0.0010
# Epoch 17/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 307886.4688 - val_loss: 302889.9688 - learning_rate: 0.0010
# Epoch 18/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 379613.1250 - val_loss: 297654.8750 - learning_rate: 0.0010
# Epoch 19/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 315020.2500 - val_loss: 287807.2812 - learning_rate: 0.0010
# Epoch 20/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 294931.0000 - val_loss: 298459.6250 - learning_rate: 0.0010
# Epoch 21/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 332489.8438 - val_loss: 289432.9375 - learning_rate: 0.0010
# Epoch 22/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 345580.0312 - val_loss: 279313.3438 - learning_rate: 0.0010
# Epoch 23/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 296187.3125 - val_loss: 289692.8750 - learning_rate: 0.0010
# Epoch 24/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 291995.7188 - val_loss: 287474.1250 - learning_rate: 0.0010
# Epoch 25/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 284332.0938 - val_loss: 279834.3750 - learning_rate: 0.0010
# Epoch 26/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 331149.2188 - val_loss: 267954.9375 - learning_rate: 0.0010
# Epoch 27/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 270296.5625 - val_loss: 263500.1562 - learning_rate: 0.0010
# Epoch 28/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 260874.3750 - val_loss: 261661.5156 - learning_rate: 0.0010
# Epoch 29/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 309417.0312 - val_loss: 260272.8281 - learning_rate: 0.0010
# Epoch 30/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 346940.0625 - val_loss: 257157.3750 - learning_rate: 0.0010
# Epoch 31/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 284828.1562 - val_loss: 250620.6250 - learning_rate: 0.0010
# Epoch 32/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 259336.4062 - val_loss: 251853.0625 - learning_rate: 0.0010
# Epoch 33/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 315331.1562 - val_loss: 248677.6406 - learning_rate: 0.0010
# Epoch 34/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 271777.9375 - val_loss: 251616.7031 - learning_rate: 0.0010
# Epoch 35/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 262536.4062 - val_loss: 248338.4688 - learning_rate: 0.0010
# Epoch 36/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 283593.7812 - val_loss: 243056.1875 - learning_rate: 0.0010
# Epoch 37/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 243817.8906 - val_loss: 239792.1719 - learning_rate: 0.0010
# Epoch 38/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 300573.5938 - val_loss: 242879.0312 - learning_rate: 0.0010
# Epoch 39/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 268916.8750 - val_loss: 237901.4375 - learning_rate: 0.0010
# Epoch 40/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 261246.7969 - val_loss: 236990.7500 - learning_rate: 0.0010
# Epoch 41/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 297188.5625 - val_loss: 233375.0156 - learning_rate: 0.0010
# Epoch 42/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 289290.2500 - val_loss: 236483.5000 - learning_rate: 0.0010
# Epoch 43/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 243623.6719 - val_loss: 239800.0938 - learning_rate: 0.0010
# Epoch 44/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 259449.7656 - val_loss: 234743.8594 - learning_rate: 0.0010
# Epoch 45/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 297777.1875 - val_loss: 236188.5000 - learning_rate: 0.0010
# Epoch 46/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 284990.3125 - val_loss: 232312.6875 - learning_rate: 0.0010
# Epoch 47/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 291582.0625 - val_loss: 250579.7656 - learning_rate: 0.0010
# Epoch 48/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 247981.8750 - val_loss: 238256.8906 - learning_rate: 0.0010
# Epoch 49/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 268025.5938 - val_loss: 241188.7500 - learning_rate: 0.0010
# Epoch 50/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 222939.6406 - val_loss: 234050.2812 - learning_rate: 0.0010
# Epoch 51/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 261558.5312 - val_loss: 225091.1719 - learning_rate: 0.0010
# Epoch 52/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 255333.0312 - val_loss: 235315.5469 - learning_rate: 0.0010
# Epoch 53/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 228989.4531 - val_loss: 222064.3594 - learning_rate: 0.0010
# Epoch 54/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 240236.0469 - val_loss: 223593.7031 - learning_rate: 0.0010
# Epoch 55/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 269326.2188 - val_loss: 234556.0156 - learning_rate: 0.0010
# Epoch 56/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 216366.7656 - val_loss: 218070.0781 - learning_rate: 0.0010
# Epoch 57/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 236368.9688 - val_loss: 216897.0000 - learning_rate: 0.0010
# Epoch 58/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 239802.2812 - val_loss: 219450.1406 - learning_rate: 0.0010
# Epoch 59/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 264061.2500 - val_loss: 210915.5625 - learning_rate: 0.0010
# Epoch 60/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 264268.4375 - val_loss: 214894.2656 - learning_rate: 0.0010
# Epoch 61/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 250800.4531 - val_loss: 209960.8906 - learning_rate: 0.0010
# Epoch 62/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 223684.4531 - val_loss: 213579.3906 - learning_rate: 0.0010
# Epoch 63/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 286317.1562 - val_loss: 211268.3281 - learning_rate: 0.0010
# Epoch 64/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 242473.5000 - val_loss: 210801.2344 - learning_rate: 0.0010
# Epoch 65/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 303623.4062 - val_loss: 208549.8125 - learning_rate: 0.0010
# Epoch 66/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 274518.5938 - val_loss: 214922.4062 - learning_rate: 0.0010
# Epoch 67/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 265298.2500 - val_loss: 209403.0156 - learning_rate: 0.0010
# Epoch 68/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 241094.1250 - val_loss: 207629.6406 - learning_rate: 0.0010
# Epoch 69/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 292448.2188 - val_loss: 211414.4531 - learning_rate: 0.0010
# Epoch 70/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 229041.9219 - val_loss: 209370.4219 - learning_rate: 0.0010
# Epoch 71/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 253989.5469 - val_loss: 210076.7500 - learning_rate: 0.0010
# Epoch 72/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 280906.5625 - val_loss: 220547.1406 - learning_rate: 0.0010
# Epoch 73/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 233262.3750 - val_loss: 209951.6719 - learning_rate: 0.0010
# Epoch 74/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 281733.9062 - val_loss: 209542.0312 - learning_rate: 5.0000e-04
# Epoch 75/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 276521.6250 - val_loss: 207917.4219 - learning_rate: 5.0000e-04
# Epoch 76/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 249033.2344 - val_loss: 206629.7656 - learning_rate: 5.0000e-04
# Epoch 77/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 253929.5312 - val_loss: 207109.9219 - learning_rate: 5.0000e-04
# Epoch 78/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 219441.9688 - val_loss: 207299.2500 - learning_rate: 5.0000e-04
# Epoch 79/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 248778.1719 - val_loss: 204624.9688 - learning_rate: 5.0000e-04
# Epoch 80/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 323297.4688 - val_loss: 206120.0625 - learning_rate: 5.0000e-04
# Epoch 81/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 237963.3125 - val_loss: 208254.8125 - learning_rate: 5.0000e-04
# Epoch 82/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 235768.3906 - val_loss: 206710.2344 - learning_rate: 5.0000e-04
# Epoch 83/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 284872.7812 - val_loss: 207100.8438 - learning_rate: 5.0000e-04
# Epoch 84/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 282081.7188 - val_loss: 205415.5625 - learning_rate: 5.0000e-04
# Epoch 85/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 228285.9688 - val_loss: 206175.9062 - learning_rate: 2.5000e-04
# Epoch 86/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 223178.0938 - val_loss: 206127.2969 - learning_rate: 2.5000e-04
# Epoch 87/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 243431.1719 - val_loss: 205115.2812 - learning_rate: 2.5000e-04
# Epoch 88/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 250303.6094 - val_loss: 203606.3125 - learning_rate: 2.5000e-04
# Epoch 89/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 233889.7188 - val_loss: 202345.3125 - learning_rate: 2.5000e-04
# Epoch 90/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 221981.4844 - val_loss: 202300.8594 - learning_rate: 2.5000e-04
# Epoch 91/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 259900.3438 - val_loss: 201141.1406 - learning_rate: 2.5000e-04
# Epoch 92/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 226724.3438 - val_loss: 202881.7188 - learning_rate: 2.5000e-04
# Epoch 93/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 244128.8906 - val_loss: 199441.2812 - learning_rate: 2.5000e-04
# Epoch 94/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 221660.7969 - val_loss: 201404.9375 - learning_rate: 2.5000e-04
# Epoch 95/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 246985.1875 - val_loss: 200512.8281 - learning_rate: 2.5000e-04
# Epoch 96/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 220696.1406 - val_loss: 199458.5156 - learning_rate: 2.5000e-04
# Epoch 97/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 262743.3750 - val_loss: 200232.7344 - learning_rate: 2.5000e-04
# Epoch 98/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 225423.9219 - val_loss: 201681.0469 - learning_rate: 2.5000e-04
# Epoch 99/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 223612.3438 - val_loss: 201576.7188 - learning_rate: 1.2500e-04
# Epoch 100/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 231603.7500 - val_loss: 200668.3438 - learning_rate: 1.2500e-04
# ✅ DFNN fine-tuning complete.

# %%
# Predict and evaluate
y_pred_val_dfnn = dfnn_finetuned.predict(X_val).flatten()

def evaluate_model(name, y_true, y_pred):
    r2 = r2_score(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    rel_rmse = (rmse / (max(y_true) - min(y_true))) * 100
    print(f"📊 {name}:")
    print(f"   R²     : {r2:.4f}")
    print(f"   MSE    : {mse:.2f}")
    print(f"   RMSE   : {rmse:.2f}")
    print(f"   MAE    : {mae:.2f}")
    print(f"   Rel RMSE: {rel_rmse:.2f}% of PPP range\n")

evaluate_model("DFNN (Fine-Tuned on Blind Well)", y_val, y_pred_val_dfnn)
# Out:
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step
# 📊 DFNN (Fine-Tuned on Blind Well):
#    R²     : 0.6757
#    MSE    : 199441.29
#    RMSE   : 446.59
#    MAE    : 333.32
#    Rel RMSE: 11.24% of PPP range

# %%
# Plot
depth_val = df_blind_val[depth_col].values
sorted_idx = np.argsort(depth_val)
plt.figure(figsize=(6, 12))
plt.plot(y_val[sorted_idx], depth_val[sorted_idx], label='Actual PPP', linewidth=2)
plt.plot(y_pred_val_dfnn[sorted_idx], depth_val[sorted_idx], label='Predicted PPP - DFNN', linestyle='--')
plt.gca().invert_yaxis()
plt.xlabel('Pore Pressure')
plt.ylabel('Depth')
plt.title('DFNN: Actual vs Predicted PPP by Depth (Blind Well)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
